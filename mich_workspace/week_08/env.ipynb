# %%
# Importing the required library for package installation
import sys

# Commands to install the necessary packages
# !{sys.executable} -m pip install torch torchvision numpy matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    --------------- ------------------------ 0.4/1.1 MB 13.5 MB/s eta 0:00:01
#    --------------------------------- ------ 1.0/1.1 MB 12.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.1/1.1 MB 12.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/192.3 MB ? eta -:--:--
#    ---------------------------------------- 0.5/192.3 MB 10.7 MB/s eta 0:00:18
#    ---------------------------------------- 1.1/192.3 MB 11.2 MB/s eta 0:00:18
#    ---------------------------------------- 1.6/192.3 MB 11.1 MB/s eta 0:00:18
#    ---------------------------------------- 2.1/192.3 MB 11.1 MB/s eta 0:00:18
#     --------------------------------------- 2.7/192.3 MB 11.3 MB/s eta 0:00:17
#     --------------------------------------- 3.2/192.3 MB 11.4 MB/s eta 0:00:17
#     --------------------------------------- 3.8/192.3 MB 11.5 MB/s eta 0:00:17
# ...
